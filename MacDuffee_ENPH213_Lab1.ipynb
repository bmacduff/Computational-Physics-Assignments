# %% [markdown]
# # ENPH 213 - Week 1 Lab
# This is a simple lab to help you get acquainted with Python and Jupyter Notebooks.
#
# When you are finished, please rename the notebook to LastName_ENPH213_Lab1, where LastName is your last name.  Submit that file to onQ.

# %% [markdown]
# ## Part 1
# Create a plot of $y = \sin(x)$ from 0 to 2$\pi$.  Remember to use Numpy for math functions and add useful comments to your code.

# %%
import math as m
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
x = np.linspace(0,2*np.pi, 100)
y = np.sin(x)
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %% [markdown]
# ## Part 2
# Save the y-data to a size column of data in a file called "LastName_Lab1-YData.txt".  Then, create a second plot that plots the above curve along with a new curve of $y = \cos(x-0.5)$.

# %%
np.savetxt("MacDuffee_Lab1-YData.txt", y)
y2 = np.cos(x-0.5)
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)
ax.plot(x,y2) #Using the same x because its the same range

# %% [markdown]
# ## Part 3
#
# Load the 5 data points from the text file supplied with the Assignment (ENPH213_Lab1-Data.txt).  Then, create a third figure that plots the y-values as data points for any 5 x-values you choose, so long as each point is discernible from each other.  The data points should be plotted along with the same curves from Part 2.

# %%
y3 = np.loadtxt("ENPH213_Lab1-Data.txt")
x3 = np.array([1,2,3,4,5])
fig = plt.figure()
ax = fig.add_axes([0,0,1,1]) 
ax.plot(x,y)
ax.plot(x,y2)
ax.plot(x3,y3, marker='o', linestyle='None') #Labeling x3 to avoid confusion

# %% [markdown]
# ## Part 4
#
# Looking at your array for $y = \sin(x)$, how can you be sure that you've plotted the entire Sine curve from 0 to $2 \pi$? (Please give 1 or 2 sentences)

# %% [markdown]
# Because the endpoints of the of the function are approximately 1 to -1.
# This is what a proper sine function should look like from the range of 0 to 2pi.

# %% [markdown]
# ## Acknowledgements
#
# Please comment on any help that you received from your group members or others concerning this Lab assignment.

# %% [markdown]
# Group members helped explain part 4 and why the sine function is definitely correct
